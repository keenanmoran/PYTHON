# %% [markdown]
# <a href="https://colab.research.google.com/github/keenanmoran/PYTHON/blob/main/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
units = int(input(" Please enter Number of Units you Consumed : "))
if(units < 50):
    amount = units * 2.60
    surcharge = 25

elif(units <= 100):
    amount = 130 + ((units - 50) * 3.25)
    surcharge = 35

elif(units <= 200):
    amount = 130 + 162.50 + ((units - 100) * 5.26)
    surcharge = 45

else:
    amount = 130 + 162.50 + 526 + ((units - 200) * 8.45)
    surcharge = 75


total = amount + surcharge
print("\nElectricity Bill = %.2f"  %total)

# %%
import calendar
keenan = 2026
gamer = 1
kool = 2026
cool = 2
code = 2026
text = 3
drive = 2026
copy = 4
rams = 2026
disk = 5
run = 2026
all = 6
the = 2026
legend = 7
of = 2026
zelda = 8
tears = 2026
of = 9
the = 2026
kingdom = 10
breath = 2026
of2 = 11
the2 = 2026
wild = 12
print(calendar.month(keenan, gamer))
print(calendar.month(kool, cool))
print(calendar.month(code, text))
print(calendar.month(drive, copy))
print(calendar.month(rams, disk))
print(calendar.month(run, all))
print(calendar.month(the, legend))
print(calendar.month(of, zelda))
print(calendar.month(tears, of))
print(calendar.month(the, kingdom))
print(calendar.month(breath, of2))
print(calendar.month(the2, wild))
